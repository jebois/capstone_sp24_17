# %%
# !pip install ultralytics==8.0.196
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Setup complete ✅ (8 CPUs, 15.6 GB RAM, 77.5/1006.9 GB disk)
#
# OS                  Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# Environment         Linux
# Python              3.10.12
# Install             pip
# RAM                 15.62 GB
# CPU                 AMD Ryzen 7 7700X 8-Core Processor
# CUDA                12.1
#
# matplotlib          ✅ 3.8.2>=3.3.0
# opencv-python       ✅ 4.9.0.80>=4.6.0
# pillow              ✅ 10.2.0>=7.1.2
# pyyaml              ✅ 5.4.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.12.0>=1.4.1
# torch               ✅ 2.2.1>=1.8.0
# torchvision         ✅ 0.17.1>=0.9.0
# tqdm                ✅ 4.66.2>=4.64.0
# psutil              ✅ 5.9.8
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 2.2.1>=1.1.4
# seaborn             ✅ 0.13.2>=0.11.0

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="omvbzjnwqAApll2fYece")
project = rf.workspace("sp2417").project("capstone-uyctt")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/home/autoraem/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=Capstone-10/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...

# %%
version = project.version(1)
version.deploy("yolov8", "/home/autoraem/projects/capstone_sp24_17/runs/detect/train15/weights/")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 version = project.version(1)
# ----> 2 version.deploy("yolov8", "/home/autoraem/projects/capstone_sp24_17/runs/detect/train15/weights/best.pt")
#
# File ~/.local/lib/python3.10/site-packages/roboflow/core/version.py:455, in Version.deploy(self, model_type, model_path)
#     449     except ImportError:
#     450         raise (
#     451             "The torch python package is required to deploy yolov5 models."
#     452             " Please install it with `pip install torch`"
#     453         )
# --> 455 model = torch.load(os.path.join(model_path, "weights/best.pt"))
#     457 if isinstance(model["model"].names, list):
#     458     class_names = model["model"].names
#
# ...
